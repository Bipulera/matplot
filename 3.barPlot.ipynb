# %%
#import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# BAR PLOT
# -bivariate
# -numerical vs categorical
# -use case- aggregate analysis of groups

# %%
children=[10,20,15,30,45,5]
colors=['red','blue','orange','pink','green','brown']

# %%
#simple bar chart
plt.bar(colors,children)
# Out:
# <BarContainer object of 6 artists>

# %%
#bar chart using data

# %%
#horizontal bar chart (vertical default)
#barh
plt.barh(colors,children)
# Out:
# <BarContainer object of 6 artists>

# %%
#color and label
children=[10,20,15,30,45,5]
colors=['red','blue','orange','pink','green','brown']
plt.bar(colors,children,color='black')
# Out:
# <BarContainer object of 6 artists>

# %%
#bar width (default=0.5)
plt.bar(colors,children,color='black',width=0.1)
# Out:
# <BarContainer object of 6 artists>

# %%
#multiple bar chart
df=pd.read_csv(r'C:\Users\HP\Desktop\all folder\matplot\matplot\batsman_season_record.csv')
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(df['batsman'],df['2015'])
plt.bar(df['batsman'],df['2016'])
plt.bar(df['batsman'],df['2017'])
# so this is not suitable
# Out:
# <BarContainer object of 5 artists>

# %%
np.arange(df.shape[0])
# Out:
# array([0, 1, 2, 3, 4])

# %%
#making bar side by side
plt.bar(np.arange(df.shape[0])-0.2 ,df['2015'], width=0.2)
plt.bar(np.arange(df.shape[0])     ,df['2016'], width=0.2)
plt.bar(np.arange(df.shape[0])+0.2 ,df['2017'], width=0.2)
#this we do to shift graph on x axis as number is subtract by -0.2 here taki year overlap na ho

#get back names (xticks)
plt.xticks(np.arange(df.shape[0]),df['batsman'])
plt.show()

# %%
#problem (category overlap)
children=[10,20,15,30,45,5]
colors=['red red red red','blue  blue blue','orange orange orange','pink','green','brown']
plt.bar(colors,children)
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'red red red red'),
#   Text(1, 0, 'blue  blue blue'),
#   Text(2, 0, 'orange orange orange'),
#   Text(3, 0, 'pink'),
#   Text(4, 0, 'green'),
#   Text(5, 0, 'brown')])

# %%
#stacked bar chart
plt.bar(df['batsman'],df['2015'] ,label=2015)
plt.bar(df['batsman'],df['2016'],bottom=df['2015'],label=2016)
plt.bar(df['batsman'],df['2017'],bottom=df['2015']+df['2016'],label=2017)
# add up years while going down
plt.legend()
