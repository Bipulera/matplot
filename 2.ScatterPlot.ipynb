# %%
#import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# scatter plot
# -bivariate
# -numerical vs numerical
# -use case - finding correlation

# %%
#plt.sactter (simple function)
x=np.linspace(-10,10,50)
y=10*x+3+np.random.randint(0,300,50)

plt.scatter(x,y)

# %%
#plt.scatter on pandas data
ipl=pd.read_csv(r'C:\Users\HP\Desktop\all folder\matplot\matplot\batter.csv')
ipl=ipl.head(50)
plt.scatter(ipl['avg'],ipl['strike_rate'],color='red',marker='>')
plt.title('avg vs str_rate compare graph of 50 batsman')
plt.xlabel('avg')
plt.ylabel('strike_rate')
# Out:
# Text(0, 0.5, 'strike_rate')

# %%
#now a dataset from seaborn to see size

# %%
#size
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#bill tip scatter plot
plt.scatter(tips['total_bill'],tips['tip'])
# size here is no of people come
plt.scatter(tips['total_bill'],tips['tip'],s=tips['size']*20,color='blue')
# size of cirles chnge

# %%
plt.plot(tips['total_bill'],tips['tip'],'o')
# 2d plot using scatter
